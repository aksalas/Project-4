# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticks
import seaborn as sns


import missingno as miss
import datetime as dt
import statsmodels.tsa.api as tsa

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is 'C:\Users\arvin\Downloads/'

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# 'C:\\Users\\arvin\\Downloads\\Crimes_-_2001_to_Present_20231026.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 0         5741943    HN549294  08/25/2007 09:22:18 AM      074XX N ROGERS AVE
# 1         1930689    HH109118  01/05/2002 09:24:00 PM          007XX E 103 ST
# 2        13203321    JG415333  09/06/2023 05:00:00 PM        002XX N Wells st
# 3        13210088    JG423627  08/31/2023 12:00:00 PM    023XX W JACKSON BLVD
# 4        13210004    JG422532  07/24/2023 09:45:00 PM    073XX S JEFFERY BLVD
# ...           ...         ...                     ...                     ...
# 7920298  13047495    JG229914  04/18/2023 08:00:00 AM    003XX N JEFFERSON ST
# 7920299  13168300    JG373901  08/07/2023 06:00:00 PM         0000X W 95TH ST
# 7920300  13114024    JG309527  06/20/2023 07:00:00 PM       031XX S AVERS AVE
# 7920301  13188860    JG398340  08/26/2023 12:00:00 AM  078XX S SOUTH SHORE DR
# 7920302  13126372    JG324067  07/01/2023 07:29:00 PM        005XX S WELLS ST
#
#          IUCR             Primary Type  \
# 0        0560                  ASSAULT
# 1        0820                    THEFT
# 2        1320          CRIMINAL DAMAGE
# 3        1153       DECEPTIVE PRACTICE
# 4        0281  CRIMINAL SEXUAL ASSAULT
# ...       ...                      ...
# 7920298  1154       DECEPTIVE PRACTICE
# 7920299  031A                  ROBBERY
# 7920300  0910      MOTOR VEHICLE THEFT
# 7920301  1320          CRIMINAL DAMAGE
# 7920302  1320          CRIMINAL DAMAGE
#
#                                      Description  \
# 0                                         SIMPLE
# 1                                 $500 AND UNDER
# 2                                     TO VEHICLE
# 3            FINANCIAL IDENTITY THEFT OVER $ 300
# 4                                 NON-AGGRAVATED
# ...                                          ...
# 7920298  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 7920299                          ARMED - HANDGUN
# 7920300                               AUTOMOBILE
# 7920301                               TO VEHICLE
# 7920302                               TO VEHICLE
#
#                            Location Description  Arrest  Domestic  ...  Ward  \
# 0                                         OTHER   False     False  ...  49.0
# 1                                   GAS STATION    True     False  ...   NaN
# 2        PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  42.0
# 3                                        STREET   False     False  ...  27.0
# 4                                     APARTMENT   False     False  ...   7.0
# ...                                         ...     ...       ...  ...   ...
# 7920298                               APARTMENT   False     False  ...  42.0
# 7920299                                SIDEWALK   False     False  ...   9.0
# 7920300                                  STREET   False     False  ...  22.0
# 7920301                                  STREET   False     False  ...   7.0
# 7920302                                  STREET   False      True  ...  34.0
#
#          Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 0                   1.0       08A           NaN          NaN  2007
# 1                   NaN        06           NaN          NaN  2002
# 2                  32.0        14           NaN          NaN  2023
# 3                  28.0        11     1160870.0    1898642.0  2023
# 4                  43.0        02     1190812.0    1856743.0  2023
# ...                 ...       ...           ...          ...   ...
# 7920298            28.0        11     1172269.0    1902384.0  2023
# 7920299            49.0        03     1177527.0    1841973.0  2023
# 7920300            30.0        07     1151205.0    1883542.0  2023
# 7920301            46.0        14     1198338.0    1853426.0  2023
# 7920302            32.0        14     1174805.0    1897873.0  2023
#
#                      Updated On   Latitude  Longitude  \
# 0        08/17/2015 03:03:40 PM        NaN        NaN
# 1        02/04/2016 06:33:39 AM        NaN        NaN
# 2        09/14/2023 03:43:09 PM        NaN        NaN
# 3        09/16/2023 03:41:56 PM  41.877565 -87.684791
# 4        09/16/2023 03:41:56 PM  41.761919 -87.576209
# ...                         ...        ...        ...
# 7920298  08/19/2023 03:40:26 PM  41.887589 -87.642827
# 7920299  08/19/2023 03:40:26 PM  41.721698 -87.625345
# 7920300  08/19/2023 03:40:26 PM  41.836324 -87.720674
# 7920301  09/02/2023 03:41:45 PM  41.752631 -87.548737
# 7920302  08/19/2023 03:40:26 PM  41.875155 -87.633649
#
#                               Location
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3         (41.877565108, -87.68479102)
# 4          (41.7619185, -87.576209245)
# ...                                ...
# 7920298  (41.887589411, -87.642826595)
# 7920299   (41.72169837, -87.625345212)
# 7920300  (41.836323827, -87.720674149)
# 7920301  (41.752631346, -87.548737069)
# 7920302   (41.87515458, -87.633648765)
#
# [7920303 rows x 22 columns]

# %%
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 56810     1310741     G001135  01/01/2001 01:00:00 PM       047XX N ELSTON AV
# 75911     1311144     G001320  01/01/2001 01:00:00 AM      063XX N LEAVITT ST
# 3049226   5462733    HN290220  01/01/2001 01:00:00 AM     058XX S INDIANA AVE
# 147932    1315987     G001152  01/01/2001 01:00:00 AM       009XX N HUDSON AV
# 94917     1325760     G001074  01/01/2001 01:00:00 PM   029XX S CALIFORNIA AV
# ...           ...         ...                     ...                     ...
# 32351    13251091    JG468931  10/18/2023 12:00:00 AM  073XX S SOUTH SHORE DR
# 32748    13247047    JG468005  10/18/2023 12:00:00 AM     019XX N WESTERN AVE
# 32540    13249969    JG471502  10/18/2023 12:00:00 AM        100XX W OHARE ST
# 32070    13254110    JG476467  10/18/2023 12:00:00 AM         005XX W 36TH ST
# 32498    13247439    JG468512  10/18/2023 12:00:00 AM      016XX W MADISON ST
#
#          IUCR                Primary Type                    Description  \
# 56810    0460                     BATTERY                         SIMPLE
# 75911    1320             CRIMINAL DAMAGE                     TO VEHICLE
# 3049226  1752  OFFENSE INVOLVING CHILDREN  AGG CRIM SEX ABUSE FAM MEMBER
# 147932   1310             CRIMINAL DAMAGE                    TO PROPERTY
# 94917    1811                   NARCOTICS   POSS: CANNABIS 30GMS OR LESS
# ...       ...                         ...                            ...
# 32351    1120          DECEPTIVE PRACTICE                        FORGERY
# 32748    0560                     ASSAULT                         SIMPLE
# 32540    0810                       THEFT                      OVER $500
# 32070    1780  OFFENSE INVOLVING CHILDREN                  OTHER OFFENSE
# 32498    0460                     BATTERY                         SIMPLE
#
#                                Location Description  Arrest  Domestic  ...  \
# 56810                       RESIDENCE PORCH/HALLWAY   False     False  ...
# 75911                                        STREET   False     False  ...
# 3049226                                   RESIDENCE   False      True  ...
# 147932                                CHA APARTMENT   False     False  ...
# 94917                  GOVERNMENT BUILDING/PROPERTY    True     False  ...
# ...                                             ...     ...       ...  ...
# 32351                                     RESIDENCE   False     False  ...
# 32748                                   CTA STATION   False     False  ...
# 32540    AIRPORT TERMINAL LOWER LEVEL - SECURE AREA   False     False  ...
# 32070                                     APARTMENT   False     False  ...
# 32498                                 CHA APARTMENT   False     False  ...
#
#          Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# 56810               NaN       08B     1145613.0     1931427.0  2001
# 75911               NaN        14     1160455.0     1942042.0  2001
# 3049226            40.0        20     1178551.0     1866538.0  2001
# 147932              NaN        14     1173036.0     1906862.0  2001
# 94917               NaN        18           NaN           NaN  2001
# ...                 ...       ...           ...           ...   ...
# 32351              43.0        10     1195265.0     1857288.0  2023
# 32748              22.0       08A     1160062.0     1912639.0  2023
# 32540              76.0        06     1100658.0     1934241.0  2023
# 32070              60.0        20           NaN           NaN  2023
# 32498              28.0       08B     1165476.0     1900090.0  2023
#
#                      Updated On   Latitude  Longitude  \
# 56810    08/17/2015 03:03:40 PM  41.967833 -87.739978
# 75911    08/17/2015 03:03:40 PM  41.996666 -87.685110
# 3049226  04/25/2007 05:57:12 AM  41.789084 -87.620849
# 147932   08/17/2015 03:03:40 PM  41.899860 -87.639877
# 94917    08/17/2015 03:03:40 PM        NaN        NaN
# ...                         ...        ...        ...
# 32351    10/25/2023 03:42:43 PM  41.763305 -87.559871
# 32748    10/25/2023 03:42:43 PM  41.915991 -87.687371
# 32540    10/25/2023 03:42:43 PM  41.976290 -87.905227
# 32070    10/25/2023 03:42:43 PM        NaN        NaN
# 32498    10/25/2023 03:42:43 PM  41.881442 -87.667838
#
#                               Location            Datetime
# 56810     (41.96783306, -87.739978195) 2001-01-01 01:00:00
# 75911     (41.99666603, -87.685109858) 2001-01-01 01:00:00
# 3049226  (41.789084341, -87.620849345) 2001-01-01 01:00:00
# 147932    (41.899860332, -87.63987705) 2001-01-01 01:00:00
# 94917                              NaN 2001-01-01 01:00:00
# ...                                ...                 ...
# 32351    (41.763305308, -87.559870854) 2023-10-18 12:00:00
# 32748    (41.915990756, -87.687370839) 2023-10-18 12:00:00
# 32540    (41.976290414, -87.905227221) 2023-10-18 12:00:00
# 32070                              NaN 2023-10-18 12:00:00
# 32498    (41.881441785, -87.667837814) 2023-10-18 12:00:00
#
# [7920303 rows x 23 columns]

# %%
chicago_full['Datetime'].dt.year
# Out:
# 56810      2001
# 75911      2001
# 3049226    2001
# 147932     2001
# 94917      2001
#            ...
# 32351      2023
# 32748      2023
# 32540      2023
# 32070      2023
# 32498      2023
# Name: Datetime, Length: 7920303, dtype: int64

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# 2002    486808
# 2001    485893
# 2003    475986
# 2004    469423
# 2005    453774
# 2006    448179
# 2007    437091
# 2008    427185
# 2009    392826
# 2010    370517
# 2011    351997
# 2012    336325
# 2013    307542
# 2014    275796
# 2016    269839
# 2017    269111
# 2018    268926
# 2015    264801
# 2019    261369
# 2022    239008
# 2020    212236
# 2021    208919
# 2023    206752
# Name: Year, dtype: int64

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["X Coordinate","Y Coordinate", "Community Area","FBI Code",
             "Case Number","Updated On",'Block','Location','IUCR']

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                    Date  \
# Datetime
# 2001-01-01 01:00:00   1310741  01/01/2001 01:00:00 PM
# 2001-01-01 01:00:00   1311144  01/01/2001 01:00:00 AM
# 2001-01-01 01:00:00   5462733  01/01/2001 01:00:00 AM
# 2001-01-01 01:00:00   1315987  01/01/2001 01:00:00 AM
# 2001-01-01 01:00:00   1325760  01/01/2001 01:00:00 PM
# ...                       ...                     ...
# 2023-10-18 12:00:00  13251091  10/18/2023 12:00:00 AM
# 2023-10-18 12:00:00  13247047  10/18/2023 12:00:00 AM
# 2023-10-18 12:00:00  13249969  10/18/2023 12:00:00 AM
# 2023-10-18 12:00:00  13254110  10/18/2023 12:00:00 AM
# 2023-10-18 12:00:00  13247439  10/18/2023 12:00:00 AM
#
#                                    Primary Type  \
# Datetime
# 2001-01-01 01:00:00                     BATTERY
# 2001-01-01 01:00:00             CRIMINAL DAMAGE
# 2001-01-01 01:00:00  OFFENSE INVOLVING CHILDREN
# 2001-01-01 01:00:00             CRIMINAL DAMAGE
# 2001-01-01 01:00:00                   NARCOTICS
# ...                                         ...
# 2023-10-18 12:00:00          DECEPTIVE PRACTICE
# 2023-10-18 12:00:00                     ASSAULT
# 2023-10-18 12:00:00                       THEFT
# 2023-10-18 12:00:00  OFFENSE INVOLVING CHILDREN
# 2023-10-18 12:00:00                     BATTERY
#
#                                        Description  \
# Datetime
# 2001-01-01 01:00:00                         SIMPLE
# 2001-01-01 01:00:00                     TO VEHICLE
# 2001-01-01 01:00:00  AGG CRIM SEX ABUSE FAM MEMBER
# 2001-01-01 01:00:00                    TO PROPERTY
# 2001-01-01 01:00:00   POSS: CANNABIS 30GMS OR LESS
# ...                                            ...
# 2023-10-18 12:00:00                        FORGERY
# 2023-10-18 12:00:00                         SIMPLE
# 2023-10-18 12:00:00                      OVER $500
# 2023-10-18 12:00:00                  OTHER OFFENSE
# 2023-10-18 12:00:00                         SIMPLE
#
#                                            Location Description  Arrest  \
# Datetime
# 2001-01-01 01:00:00                     RESIDENCE PORCH/HALLWAY   False
# 2001-01-01 01:00:00                                      STREET   False
# 2001-01-01 01:00:00                                   RESIDENCE   False
# 2001-01-01 01:00:00                               CHA APARTMENT   False
# 2001-01-01 01:00:00                GOVERNMENT BUILDING/PROPERTY    True
# ...                                                         ...     ...
# 2023-10-18 12:00:00                                   RESIDENCE   False
# 2023-10-18 12:00:00                                 CTA STATION   False
# 2023-10-18 12:00:00  AIRPORT TERMINAL LOWER LEVEL - SECURE AREA   False
# 2023-10-18 12:00:00                                   APARTMENT   False
# 2023-10-18 12:00:00                               CHA APARTMENT   False
#
#                      Domestic  Beat  District  Ward  Year   Latitude  \
# Datetime
# 2001-01-01 01:00:00     False  1722      17.0   NaN  2001  41.967833
# 2001-01-01 01:00:00     False  2413      24.0   NaN  2001  41.996666
# 2001-01-01 01:00:00      True   233       2.0  20.0  2001  41.789084
# 2001-01-01 01:00:00     False  1823      18.0   NaN  2001  41.899860
# 2001-01-01 01:00:00     False  1033      10.0   NaN  2001        NaN
# ...                       ...   ...       ...   ...   ...        ...
# 2023-10-18 12:00:00     False   334       3.0   7.0  2023  41.763305
# 2023-10-18 12:00:00     False  1434      14.0   1.0  2023  41.915991
# 2023-10-18 12:00:00     False  1651      16.0  41.0  2023  41.976290
# 2023-10-18 12:00:00     False   915       9.0  11.0  2023        NaN
# 2023-10-18 12:00:00     False  1224      12.0  27.0  2023  41.881442
#
#                      Longitude
# Datetime
# 2001-01-01 01:00:00 -87.739978
# 2001-01-01 01:00:00 -87.685110
# 2001-01-01 01:00:00 -87.620849
# 2001-01-01 01:00:00 -87.639877
# 2001-01-01 01:00:00        NaN
# ...                        ...
# 2023-10-18 12:00:00 -87.559871
# 2023-10-18 12:00:00 -87.687371
# 2023-10-18 12:00:00 -87.905227
# 2023-10-18 12:00:00        NaN
# 2023-10-18 12:00:00 -87.667838
#
# [7920303 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2003.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2004.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2005.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2006.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2007.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2008.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2009.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2010.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2011.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2012.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2013.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2014.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2015.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2016.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2017.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2018.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2019.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2020.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2021.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2022.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago\\Chicago-Crime_2001.csv']
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f) for f in crime_files])
df
# Out:
#               ID                    Date                Primary Type  \
# 0        1310741  01/01/2001 01:00:00 PM                     BATTERY
# 1        1311144  01/01/2001 01:00:00 AM             CRIMINAL DAMAGE
# 2        5462733  01/01/2001 01:00:00 AM  OFFENSE INVOLVING CHILDREN
# 3        1315987  01/01/2001 01:00:00 AM             CRIMINAL DAMAGE
# 4        1325760  01/01/2001 01:00:00 PM                   NARCOTICS
# ...          ...                     ...                         ...
# 206747  13251091  10/18/2023 12:00:00 AM          DECEPTIVE PRACTICE
# 206748  13247047  10/18/2023 12:00:00 AM                     ASSAULT
# 206749  13249969  10/18/2023 12:00:00 AM                       THEFT
# 206750  13254110  10/18/2023 12:00:00 AM  OFFENSE INVOLVING CHILDREN
# 206751  13247439  10/18/2023 12:00:00 AM                     BATTERY
#
#                           Description  \
# 0                              SIMPLE
# 1                          TO VEHICLE
# 2       AGG CRIM SEX ABUSE FAM MEMBER
# 3                         TO PROPERTY
# 4        POSS: CANNABIS 30GMS OR LESS
# ...                               ...
# 206747                        FORGERY
# 206748                         SIMPLE
# 206749                      OVER $500
# 206750                  OTHER OFFENSE
# 206751                         SIMPLE
#
#                               Location Description  Arrest  Domestic  Beat  \
# 0                          RESIDENCE PORCH/HALLWAY   False     False  1722
# 1                                           STREET   False     False  2413
# 2                                        RESIDENCE   False      True   233
# 3                                    CHA APARTMENT   False     False  1823
# 4                     GOVERNMENT BUILDING/PROPERTY    True     False  1033
# ...                                            ...     ...       ...   ...
# 206747                                   RESIDENCE   False     False   334
# 206748                                 CTA STATION   False     False  1434
# 206749  AIRPORT TERMINAL LOWER LEVEL - SECURE AREA   False     False  1651
# 206750                                   APARTMENT   False     False   915
# 206751                               CHA APARTMENT   False     False  1224
#
#         District  Ward   Latitude  Longitude
# 0           17.0   NaN  41.967833 -87.739978
# 1           24.0   NaN  41.996666 -87.685110
# 2            2.0  20.0  41.789084 -87.620849
# 3           18.0   NaN  41.899860 -87.639877
# 4           10.0   NaN        NaN        NaN
# ...          ...   ...        ...        ...
# 206747       3.0   7.0  41.763305 -87.559871
# 206748      14.0   1.0  41.915991 -87.687371
# 206749      16.0  41.0  41.976290 -87.905227
# 206750       9.0  11.0        NaN        NaN
# 206751      12.0  27.0  41.881442 -87.667838
#
# [7920303 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    485893
# 2002    486808
# 2003    475986
# 2004    469423
# 2005    453774
# 2006    448179
# 2007    437091
# 2008    427185
# 2009    392826
# 2010    370517
# 2011    351997
# 2012    336325
# 2013    307542
# 2014    275796
# 2015    264801
# 2016    269839
# 2017    269111
# 2018    268926
# 2019    261369
# 2020    212236
# 2021    208919
# 2022    239008
# 2023    206752
# Name: Date, dtype: int64

# %%
df.head()
# Out:
#         ID                    Date                Primary Type  \
# 0  1310741  01/01/2001 01:00:00 PM                     BATTERY
# 1  1311144  01/01/2001 01:00:00 AM             CRIMINAL DAMAGE
# 2  5462733  01/01/2001 01:00:00 AM  OFFENSE INVOLVING CHILDREN
# 3  1315987  01/01/2001 01:00:00 AM             CRIMINAL DAMAGE
# 4  1325760  01/01/2001 01:00:00 PM                   NARCOTICS
#
#                      Description          Location Description  Arrest  \
# 0                         SIMPLE       RESIDENCE PORCH/HALLWAY   False
# 1                     TO VEHICLE                        STREET   False
# 2  AGG CRIM SEX ABUSE FAM MEMBER                     RESIDENCE   False
# 3                    TO PROPERTY                 CHA APARTMENT   False
# 4   POSS: CANNABIS 30GMS OR LESS  GOVERNMENT BUILDING/PROPERTY    True
#
#    Domestic  Beat  District  Ward   Latitude  Longitude
# 0     False  1722      17.0   NaN  41.967833 -87.739978
# 1     False  2413      24.0   NaN  41.996666 -87.685110
# 2      True   233       2.0  20.0  41.789084 -87.620849
# 3     False  1823      18.0   NaN  41.899860 -87.639877
# 4     False  1033      10.0   NaN        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7920303 entries, 0 to 206751
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  object
#  2   Primary Type          object
#  3   Description           object
#  4   Location Description  object
#  5   Arrest                bool
#  6   Domestic              bool
#  7   Beat                  int64
#  8   District              float64
#  9   Ward                  float64
#  10  Latitude              float64
#  11  Longitude             float64
# dtypes: bool(2), float64(4), int64(2), object(4)
# memory usage: 679.8+ MB

# %%
df['Date'][534]
# Out:
# 534    01/01/2001 05:00:00 PM
# 534    01/01/2002 04:34:00 PM
# 534    01/01/2003 04:55:00 PM
# 534    01/01/2004 04:30:00 PM
# 534    01/01/2005 04:39:00 PM
# 534    01/01/2006 04:53:37 PM
# 534    01/01/2007 04:45:00 AM
# 534    01/01/2008 05:30:00 AM
# 534    01/01/2009 05:00:00 PM
# 534    01/01/2010 07:00:00 PM
# 534    01/01/2011 05:20:00 AM
# 534    01/01/2012 06:00:00 AM
# 534    01/01/2013 06:15:00 AM
# 534    01/01/2014 08:00:00 AM
# 534    01/01/2015 08:19:00 AM
# 534    01/01/2016 08:30:00 PM
# 534    01/01/2017 08:00:00 PM
# 534    01/01/2018 10:00:00 AM
# 534    01/01/2019 08:00:00 AM
# 534    01/01/2020 09:00:00 AM
# 534    01/01/2021 12:00:00 AM
# 534    01/01/2022 12:00:00 AM
# 534    01/01/2023 08:25:00 PM
# Name: Date, dtype: object

# %%
fmt = "%m/%d/%Y %I:%M:%S %p"

# %%
df['Date'] = pd.to_datetime(df['Date'], format=fmt)  # Convert the 'Date' column to datetime
df.set_index('Date', inplace=True)  # Set the 'Date' column as the index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [58], line 1
# ----> 1 df['Date'] = pd.to_datetime(df['Date'], format=fmt)  # Convert the 'Date' column to datetime
#       2 df.set_index('Date', inplace=True)  # Set the 'Date' column as the index
#       3 df.head()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
df.head()
# Out:
#                           ID                Primary Type  \
# Date
# 2001-01-01 13:00:00  1310741                     BATTERY
# 2001-01-01 01:00:00  1311144             CRIMINAL DAMAGE
# 2001-01-01 01:00:00  5462733  OFFENSE INVOLVING CHILDREN
# 2001-01-01 01:00:00  1315987             CRIMINAL DAMAGE
# 2001-01-01 13:00:00  1325760                   NARCOTICS
#
#                                        Description  \
# Date
# 2001-01-01 13:00:00                         SIMPLE
# 2001-01-01 01:00:00                     TO VEHICLE
# 2001-01-01 01:00:00  AGG CRIM SEX ABUSE FAM MEMBER
# 2001-01-01 01:00:00                    TO PROPERTY
# 2001-01-01 13:00:00   POSS: CANNABIS 30GMS OR LESS
#
#                              Location Description  Arrest  Domestic  Beat  \
# Date
# 2001-01-01 13:00:00       RESIDENCE PORCH/HALLWAY   False     False  1722
# 2001-01-01 01:00:00                        STREET   False     False  2413
# 2001-01-01 01:00:00                     RESIDENCE   False      True   233
# 2001-01-01 01:00:00                 CHA APARTMENT   False     False  1823
# 2001-01-01 13:00:00  GOVERNMENT BUILDING/PROPERTY    True     False  1033
#
#                      District  Ward   Latitude  Longitude
# Date
# 2001-01-01 13:00:00      17.0   NaN  41.967833 -87.739978
# 2001-01-01 01:00:00      24.0   NaN  41.996666 -87.685110
# 2001-01-01 01:00:00       2.0  20.0  41.789084 -87.620849
# 2001-01-01 01:00:00      18.0   NaN  41.899860 -87.639877
# 2001-01-01 13:00:00      10.0   NaN        NaN        NaN

# %%
df_ts.info
# Out:
# <bound method Series.info of 0        2001-01-01 13:00:00
# 1        2001-01-01 01:00:00
# 2        2001-01-01 01:00:00
# 3        2001-01-01 01:00:00
# 4        2001-01-01 13:00:00
#                  ...
# 206747   2023-10-18 00:00:00
# 206748   2023-10-18 00:00:00
# 206749   2023-10-18 00:00:00
# 206750   2023-10-18 00:00:00
# 206751   2023-10-18 00:00:00
# Name: Date, Length: 7920303, dtype: datetime64[ns]>

# %%
df_ts = df.copy()
df_district = df_ts.groupby('District').resample('Y').size()
df_district
# Out:
# District  Date
# 1.0       2001-12-31    14861
#           2002-12-31    17974
#           2003-12-31    17571
#           2004-12-31    17579
#           2005-12-31    17700
#                         ...
# 31.0      2019-12-31        7
#           2020-12-31        4
#           2021-12-31       15
#           2022-12-31       15
#           2023-12-31       12
# Length: 530, dtype: int64

# %%
df_district_unstacked = df_ts.unstack(level=0)
df_district_unstacked.head()
# Out:
#     Date
# ID  2001-01-01 13:00:00    1310741
#     2001-01-01 01:00:00    1311144
#     2001-01-01 01:00:00    5462733
#     2001-01-01 01:00:00    1315987
#     2001-01-01 13:00:00    1325760
# dtype: object

# %%
df_district_unstacked.loc['2001':]
# Out:
#            Date
# ID         2001-01-01 13:00:00      1310741
#            2001-01-01 01:00:00      1311144
#            2001-01-01 01:00:00      5462733
#            2001-01-01 01:00:00      1315987
#            2001-01-01 13:00:00      1325760
#                                     ...
# Longitude  2023-10-18 00:00:00   -87.559871
#            2023-10-18 00:00:00   -87.687371
#            2023-10-18 00:00:00   -87.905227
#            2023-10-18 00:00:00          NaN
#            2023-10-18 00:00:00   -87.667838
# Length: 87123333, dtype: object

# %%
df_district_unstacked.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [77], line 1
# ----> 1 df_district_unstacked.plot()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\plotting\_matplotlib\core.py:450, in MPLPlot.generate(self)
#     448 def generate(self) -> None:
#     449     self._args_adjust()
# --> 450     self._compute_plot_data()
#     451     self._setup_subplots()
#     452     self._make_plot()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\plotting\_matplotlib\core.py:635, in MPLPlot._compute_plot_data(self)
#     633 # no non-numeric frames or series allowed
#     634 if is_empty:
# --> 635     raise TypeError("no numeric data to plot")
#     637 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
plt.rcParams['figure.figsize'] = [10,5]

# %%
df_years.plot()
# Out:
# <Axes: xlabel='Date'>
